# %%
# !pip install pandas
# !pip install QuantLib
# Out:
# Requirement already satisfied: pandas in d:\projects\pythonproject\oe\oe_trading_api\venv\lib\site-packages (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\projects\pythonproject\oe\oe_trading_api\venv\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\projects\pythonproject\oe\oe_trading_api\venv\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in d:\projects\pythonproject\oe\oe_trading_api\venv\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.20.3 in d:\projects\pythonproject\oe\oe_trading_api\venv\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in d:\projects\pythonproject\oe\oe_trading_api\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: QuantLib in d:\projects\pythonproject\oe\oe_trading_api\venv\lib\site-packages (1.30)

# %%
import pandas as pd
import QuantLib as ql

from app.service.YieldCurve.NoteBooks import NotebookHelper

# %matplotlib inline

# %% [raw]
# Here is defined some input based on yield Swiss Tresury Bonds.
# Source: http://www.worldgovernmentbonds.com/country/switzerland/

# %%
swiss_bonds = NotebookHelper.swiss_bonds

# %% [raw]
# This section defines the main variables

# %%
settings = NotebookHelper.Settings()

# %% [raw]
# This section build the instruments using the tenor and yields from the Yield Goverment Bonds

# %%
raw_index_tenor = []
raw_yield = []
helpers = ql.RateHelperVector()
for point in swiss_bonds['benchmark_points']:
    rate = point['rate']
    tenor = NotebookHelper.get_tenor(point['tenor'])

    raw_yield.append(rate)
    raw_index_tenor.append(settings.today + tenor)

    helpers.append(ql.DepositRateHelper(rate,
                                   tenor,
                                   settings.fixing_days,
                                   settings.calendar,
                                   settings.convention,
                                   settings.end_of_month,
                                   settings.day_counter))

df_raw_yields = pd.DataFrame(index=raw_index_tenor, columns=['Yield'], data=raw_yield)
display(df_raw_yields)
# Out:
#                        Yield
# June 7th, 2023       0.01500
# July 7th, 2023       0.01340
# August 7th, 2023     0.01450
# September 7th, 2023  0.01460
# December 7th, 2023   0.01580
# June 7th, 2024       0.01770
# June 7th, 2025       0.01068
# June 7th, 2026       0.00951
# June 7th, 2027       0.00798
# June 7th, 2028       0.00806
# June 7th, 2029       0.00800
# June 7th, 2030       0.00802
# June 7th, 2031       0.00811
# June 7th, 2032       0.00840
# June 7th, 2033       0.00853

# %%
df_raw_yields.plot(figsize=(15,5), ylabel='Yield', xlabel='Tenor', grid=True, title='Swiss Government Bonds')
# Out:
# <Axes: title={'center': 'Swiss Government Bonds'}, xlabel='Tenor', ylabel='Yield'>

# %% [raw]
# Here is defined the different piecewise methods

# %%
params = [settings.fixing_days, settings.calendar, helpers, settings.day_counter]

methods_curves = {
    "PiecewiseFlatForward": ql.PiecewiseFlatForward(*params),
    #"LogLinearDiscount": ql.PiecewiseLogLinearDiscount(*params),
    "LogCubicDiscount": ql.PiecewiseLogCubicDiscount(*params),
    "LinearZero": ql.PiecewiseLinearZero(*params),
    #"CubicZero": ql.PiecewiseCubicZero(*params),
    #  "LinearForward": ql.PiecewiseLinearForward(*params),
    #SplineCubicDiscount": ql.PiecewiseSplineCubicDiscount(*params)
}

df_index_tenors = pd.DataFrame(index=[row[0] for row in list(methods_curves.values())[0].nodes()])
[methods_curves[curve].enableExtrapolation() for curve in methods_curves]
end_date = list(methods_curves.values())[0].maxDate()
curve_dates = [ ql.Date(serial) for serial in range(settings.today.serialNumber(), end_date.serialNumber()+1) ]
index_curve_name = methods_curves.keys()

display(df_index_tenors)
# Out:
# Empty DataFrame
# Columns: []
# Index: [June 7th, 2023, July 7th, 2023, August 7th, 2023, September 7th, 2023, December 7th, 2023, June 7th, 2024, June 10th, 2025, June 8th, 2026, June 7th, 2027, June 7th, 2028, June 7th, 2029, June 7th, 2030, June 9th, 2031, June 7th, 2032, June 7th, 2033]

# %%
NotebookHelper.plot_forward_rates(curve_dates, methods_curves, settings, index_curve_name, df_raw_yields)
# Out:
# 0 - June 7th, 2023: 0.015
# 1 - July 7th, 2023: 0.0134
# 2 - August 7th, 2023: 0.0145
# 3 - September 7th, 2023: 0.0146
# 4 - December 7th, 2023: 0.0158
# 5 - June 7th, 2024: 0.0177
# 6 - June 7th, 2025: 0.01068
# 7 - June 7th, 2026: 0.00951
# 8 - June 7th, 2027: 0.00798
# 9 - June 7th, 2028: 0.00806
# 10 - June 7th, 2029: 0.008
# 11 - June 7th, 2030: 0.00802
# 12 - June 7th, 2031: 0.00811
# 13 - June 7th, 2032: 0.0084
# 14 - June 7th, 2033: 0.00853

# %%
NotebookHelper.plot_zero_rates(curve_dates, methods_curves, settings, index_curve_name, df_raw_yields)
# Out:
# 0 - June 7th, 2023: 0.015
# 1 - July 7th, 2023: 0.0134
# 2 - August 7th, 2023: 0.0145
# 3 - September 7th, 2023: 0.0146
# 4 - December 7th, 2023: 0.0158
# 5 - June 7th, 2024: 0.0177
# 6 - June 7th, 2025: 0.01068
# 7 - June 7th, 2026: 0.00951
# 8 - June 7th, 2027: 0.00798
# 9 - June 7th, 2028: 0.00806
# 10 - June 7th, 2029: 0.008
# 11 - June 7th, 2030: 0.00802
# 12 - June 7th, 2031: 0.00811
# 13 - June 7th, 2032: 0.0084
# 14 - June 7th, 2033: 0.00853

# %%
NotebookHelper.plot_discount(curve_dates, methods_curves, settings, index_curve_name)
